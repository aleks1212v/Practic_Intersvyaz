# %%
#разбиваем всю БД каждые 10000 строк на разделы lim 
import pymysql.cursors
import pandas as pd
import numpy as np

import re
import emoji

import pymorphy2
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords
stops = set(stopwords.words("english")) | set(stopwords.words("russian"))

# препроцессинг

def preprocess_text(text):
    def replace_three_or_more(text):
        pattern = re.compile(r"(.)\1{2,}", re.DOTALL)
        return pattern.sub(r"\1\1", text)

    def emo_to_text(text):  
        emoticon = {'улыбка шутка' : ['\:\)', '\:\-\)', '\:\=\)'],
                    'грусть разочарование' : ['\:\(', '\:\-\(', '\:\=\('],
                    'открытая радость' : ['\=\)', '\=\-\)'],
                    'усмешка хихиканье' : ['\:>', '\:\->', '\:\=>'],
                    'улыбка' : ['\:\]', '\:\-\]', '\:\=\]'],
                    'смех' : ['\:D', '\:\-D', '\:\=D'],
                    'сильный смех' : ['\:DD', '\:\-DD', '\:\=DD'],
                    'сарказм' : ['\:\}', '\:\-\}', '\:\=\}'],
                    'подмигивание заигрывание' : ['\;\)', '\;\-\)', '\;\=\)'],
                    'молчание' : ['\:Х', '\:\-Х', '\:\=Х'],
                    'удивленное разочарование' : ['8\(', '8\-\(', '8\=\('],
                    'изумление' : ['B\-о', 'B\=о'],
                    'радостное удивление' : ['\%\)'],
                    'зевота' : ['\|\-o', '\|\=o'],
                    'смущение' : ['\:S', '\:-S', '\:\=S'],
                    'равнодушие скука' : ['\:\|', '\:\-\|', '\:\=\|'],
                    'недоверие сомнение' : ['\:\/', '\:\-\/', '\:\=\/'],
                    'дразнящее показывание языка' : ['\:ь', '\:\-ь', '\:\=ь'],
                    'поцелуй' : ['\:\*', '\:\^\*', '\:\-Ф'],
                    'шалость дурачество' : ['\:0\)'],
                    'кривая ухмылка' : ['\:7', '\:\-7']}

        for key, value in emoticon.items():
          text = re.sub(r"|".join(value), ' ' + key, text)
        return text

    try:
      text = emo_to_text(text)
      text = emoji.demojize(text, delimiters=("", "")) #преобразует эмодзи-символы в слова
      text = text.lower().replace("ё", "е")
      text = re.sub('((www\.[^\s]+)|(https?://[^\s]+))', 'URL', text)
      text = re.sub('@[^\s]+', 'USER', text)
      text = re.sub('[^a-zA-Zа-яА-Я]+', ' ', text) #удаляем цифры и спецсимволы
      text = replace_three_or_more(text) #удаляет дублирование букв, если число букв более 3
      text = re.sub(' +', '|', text)
      return text.strip()
    except:
      print(f'Слово {text} не прошло препроцессинг')
      return ''

# Connect to the database
def get_connection():
    connection = pymysql.connect(host='database-3.chim8btj05zt.us-east-1.rds.amazonaws.com',
                                 user='admin',
                                 password='01035007',
                                 db='test1',
                                 charset='utf8mb4',
                                 cursorclass=pymysql.cursors.DictCursor)
    return connection


connection = get_connection()

morph = pymorphy2.MorphAnalyzer() #по умолчанию русский язык
stemmer = SnowballStemmer("english")

LIM = 100000 #число проходов по БД
try:
    with connection.cursor() as cursor:
        s = "SELECT min(id), max(id) FROM sentiment"
        cursor.execute(s)
        start, stop = cursor.fetchone().values()
        start = 418385459967184897 + 1
        delta = (stop - start) // LIM #интервал id, в котором искать значения в каждом проходе

        #cursor.execute("DROP TABLE IF EXISTS sentiment_v3")
        #connection.commit()
        cursor.execute("""CREATE TABLE IF NOT EXISTS sentiment_v3(
              id bigint(32) NOT NULL PRIMARY KEY,
              tdate varchar(128) DEFAULT NULL,
              tname varchar(128) DEFAULT NULL,
              ttext_stem varchar(256) DEFAULT NULL,
              ttext_prep varchar(256) DEFAULT NULL,
              ttext varchar(256) DEFAULT NULL,
              ttype int(10) DEFAULT '0',
              trep int(10) DEFAULT '0',
              trtw int(10) DEFAULT '0',
              tfav int(10) DEFAULT '0',
              tstcount int(10) DEFAULT '0',
              tfoll int(10) DEFAULT '0',
              tfrien int(10) DEFAULT '0',
              listcount int(10) DEFAULT '0') DEFAULT CHARSET=utf8mb4""")
        connection.commit()

        while stop > start:
          try:
            s = "SELECT * FROM sentiment WHERE id >= %s AND id < %s"
            cursor.execute(s, (start, start + delta))
            start = start + delta
            result = cursor.fetchall()
            raw_data = pd.DataFrame(result, index = None)
            
            print(f"В датафрейм загружены прецеденты в количестве {raw_data.shape[0]}")

            #препроцессинг
            if raw_data.shape[0] > 0:
              print(f"Первая строка: {raw_data.head(1)}")
              raw_data['ttext_prep'] = raw_data['ttext'].apply(preprocess_text)

            else:
              continue
                                   

            #стемминг
            ttext_stem = list()
            for row in raw_data.itertuples():
                words = row.ttext_prep.split('|')
                nf_words = list()
                for word in words:
                  try:
                    #word = word.encode('utf8mb4')
                    ru_word = re.sub('[^а-яА-Я]+', ' ', word)
                    en_word = re.sub('[^a-zA-Z]+', ' ', word)
                    if ru_word == word and word != '': # кириллица
                      parse_word = morph.parse(word)[0]
                      nf_word = parse_word.normal_form
                      nf_words.append(nf_word.strip())
                    elif en_word == word and word != '': # латиница
                      nf_word = stemmer.stem(word)
                      nf_words.append(nf_word.strip())
                    else:
                      pass #смешанные слова не анализируются
                  except:
                    print(f'Слово не преобразовано') 
                    continue
                nf_words = [w for w in nf_words if not w in stops]
                nf_words = '|'.join(nf_words) #ttext_stem
                ttext_stem.append(nf_words)

            if ttext_stem != None:
                ttext_stem = pd.Series(ttext_stem) 
                raw_data['ttext_stem'] = ttext_stem  
                s =  "%s, " * 13 + "%s)"
                insert = "INSERT INTO sentiment_v3 VALUES (" + s    
                for row in raw_data.itertuples():
                    cursor.execute(insert, (row.id, row.tdate,
                                            row.tname, row.ttext_stem, row.ttext_prep, row.ttext,
                                            row.ttype, row.trep,
                                            row.trtw, row.tfav,
                                            row.tstcount, row.tfoll,
                                            row.tfrien, row.listcount))
                connection.commit()
          except Exception as e:
            print(f"Ошибка итерации while. {e}")
            continue
        print("Конвертация завершена")
        
finally:
    connection.close()
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 0
# В датафрейм загружены прецеденты в количестве 194
# Первая строка:                    id       tdate         tname  ... tfoll  tfrien  listcount
# 0  418613053413154816  1388640104  nyxasyrewyde  ...     4       0          0
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 595
# Первая строка:                    id       tdate   tname  ... tfoll  tfrien  listcount
# 0  418613165589798912  1388640130  avtorT  ...  1021     999         28
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 590
# Первая строка:                    id       tdate      tname  ... tfoll  tfrien  listcount
# 0  418613416451121152  1388640190  rdukNeuwi  ...   154     615          0
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 545
# Первая строка:                    id       tdate        tname  ... tfoll  tfrien  listcount
# 0  418613656767954944  1388640247  topfastnews  ...   349      12          7
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 545
# Первая строка:                    id       tdate            tname  ... tfoll  tfrien  listcount
# 0  418613862754439168  1388640297  KovalskyPenguin  ...   218     220          2
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 589
# Первая строка:                    id       tdate    tname  ... tfoll  tfrien  listcount
# 0  418614104438607873  1388640354  alvekon  ...    75     105          1
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 495
# Первая строка:                    id       tdate       tname  ... tfoll  tfrien  listcount
# 0  418614350354472961  1388640413  calm_misty  ...     0       6          0
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 541
# Первая строка:                    id       tdate      tname  ... tfoll  tfrien  listcount
# 0  418614564637253632  1388640464  mila_svon  ...    11      10          0
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 571
# Первая строка:                    id       tdate         tname  ... tfoll  tfrien  listcount
# 0  418614793059057664  1388640518  mgl_greenman  ...   207     344          0
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 555
# Первая строка:                    id       tdate            tname  ... tfoll  tfrien  listcount
# 0
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 494
# Первая строка:                    id       tdate          tname  ... tfoll  tfrien  listcount
# 0  419015102482759681  1388735960  TeamYandexNew  ...   117      28          0
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 595
# Первая строка:                    id       tdate     tname  ... tfoll  tfrien  listcount
# 0  419015313897062400  1388736010  tenfasa1  ...   220     186          0
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 594
# Первая строка:                    id       tdate     tname  ... tfoll  tfrien  listcount
# 0  419015550879019009  1388736066  ilgams82  ...    58      37          0
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 495
# Первая строка:                    id       tdate           tname  ... tfoll  tfrien  listcount
# 0  419015794476195840  1388736125  _0096214850321  ...   104     136          0
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 504
# Первая строка:                    id       tdate       tname  ... tfoll  tfrien  listcount
# 0  419016010923245568  1388736176  Dennitsa84  ...    40     412          0
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 581
# Первая строка:                    id       tdate         tname  ... tfoll  tfrien  listcount
# 0  419016241991667712  1388736231  wecixojaxedu  ...   157     236          0
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 587
# Первая строка:                    id       tdate            tname  ... tfoll  tfrien  listcount
# 0  419016479120846848  1388736288  smolnaberezhnay  ...    65     124          1
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 593
# Первая строка:                    id       tdate      tname  ... tfoll  tfrien  listcount
# 0  419016721228632064  1388736345  MOS_GOVNO  ...    66      59          1
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 589
# Первая строка:                    id       tdate    tname  ... tfoll  tfrien  listcount
# 0  419016961347969025  1388736403  eblanyu  ...     6      11          0
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 470
# Первая строка:                    id       tdate            tname  ... tfoll  tfrien  listcount
# 0  419017204386893824  1388736461  lesiacutsenkova  ...     6      12          0
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 551
# Первая строка:                    id       tdate    tname  ... tfoll  tfrien  listcount
# 0  419017404815925249  1388736508  Velotur  ...   838    1384         31
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 457
# Первая строка:                    id       tdate        tname  ... tfoll  tfrien  listcount
# 0  419017637663100928  1388736564  qozapyxoret  ...    74     181          0
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 594
# Первая строка:                    id       tdate         tname  ... tfoll  tfrien  listcount
# 0  419017876734222336  1388736621  ___KAKAXA___  ...   817     230         15
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 587
# Первая строка:                    id       tdate    tname  ... tfoll  tfrien  listcount
# 0  419018108343709696  1388736676  dimvsam  ...     4      23          0
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 567
# Первая строка:                    id       tdate           tname  ... tfoll  tfrien  listcount
# 0  419018352779362305  1388736734  DeanSosetUCasA  ...   284     461          0
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 510
# Первая строка:                    id       tdate            tname  ... tfoll  tfrien  listcount
# 0  419018567829307392  1388736786  NataliPotapenko  ...    38      51          2
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 589
# Первая строка:                    id       tdate         tname  ... tfoll  tfrien  listcount
# 0  419018819542466560  1388736846  alina_sh221b  ...  1477     186         41
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 576
# Первая строка:                    id       tdate     tname  ... tfoll  tfrien  listcount
# 0  419019070303141889  1388736906  omzigaom  ...  1562    1579         30
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 510
# Первая строка:                    id       tdate           tname  ... tfoll  tfrien  listcount
# 0  419019265539190785  1388736952  LetoForest_bot  ...  1810    1968          3
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 494
# Первая строка:                    id       tdate       tname  ... tfoll  tfrien  listcount
# 0  419019502362558464  1388737009  alipiyalex  ...     2      38          0
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 596
# Первая строка:                    id       tdate           tname  ... tfoll  tfrien  listcount
# 0  419019739235909632  1388737065  PolinaBiktasha  ...    38      30          0
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 492
# Первая строка:                    id       tdate      tname  ... tfoll  tfrien  listcount
# 0  419019995428192256  1388737126  ykofedhma  ...     7       6          0
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 591
# Первая строка:                    id       tdate        tname  ... tfoll  tfrien  listcount
# 0  419020200558616576  1388737175  ryoutanreta  ...  2103      34          0
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 598
# Первая строка:                    id       tdate           tname  ... tfoll  tfrien  listcount
# 0  419020440053768193  1388737232  juliaytihonova  ...   750     290         15
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 493
# Первая строка:                    id       tdate      tname  ... tfoll  tfrien  listcount
# 0  419020696933920768  1388737293  zinesheva  ...    42      22          0
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 587
# Первая строка:                    id       tdate       tname  ... tfoll  tfrien  listcount
# 0  419020896297177088  1388737341  SylviaElla  ...    56       0          2
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 593
# Первая строка:                    id       tdate        tname  ... tfoll  tfrien  listcount
# 0  419021135305777152  1388737398  fuwimifatik  ...   142     159          0
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 591
# Первая строка:                    id       tdate       tname  ... tfoll  tfrien  listcount
# 0  419021376423333888  1388737455  ruth190983  ...    39     125          1
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 494
# Первая строка:                    id       tdate         tname  ... tfoll  tfrien  listcount
# 0  419021641176186880  1388737518  slresmeehjra  ...  1566    1838        341
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 591
# Первая строка:                    id       tdate   tname  ... tfoll  tfrien  listcount
# 0  419021838266544129  1388737565  BNazka  ...     8      22          0
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 592
# Первая строка:                    id       tdate         tname  ... tfoll  tfrien  listcount
# 0  419022076402757632  1388737622  aflegontova1  ...    77      70          0
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 592
# Первая строка:                    id       tdate      tname  ... tfoll  tfrien  listcount
# 0  419022316379459584  1388737679  Tre_Timon  ...    46      20          0
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 582
# Первая строка:                    id       tdate         tname  ... tfoll  tfrien  listcount
# 0  419022547624022016  1388737735  brkln_alinaa  ...    32      97          0
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 511
# Первая строка:                    id       tdate      tname  ... tfoll  tfrien  listcount
# 0  419022754382626816  1388737784  KidsTV_co  ...    85      34          1
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 591
# Первая строка:                    id       tdate       tname  ... tfoll  tfrien  listcount
# 0  419022997501255681  1388737842  vandugoman  ...  1598     187         57
#
# [1 rows x 12 columns]
# В датафрейм загружены прецеденты в количестве 594
# Первая строка:                    id       tdate      tname  ... tfoll  tfrien  listcount
# 0  419023233094914048  1388737898  thMarcink  ...     4       3          0
#
# [1 rows x 12 columns]
